# %% [markdown]
# # Automate The Boring Stuff With Python by AL SWEIGART

# %% [markdown]
# # Entering Expressions into the Interactive Shell

# %%
2+2
# Out:
# 4

# %%
# In Python, 2+2 is called an expression. Expressions consist of values and operators and they can evaluate down to a single value.

# %%
2
# Out:
# 2

# %%
# A single value with no operators is also considered an expression, though it evaluates only to itself.

# %%
2+3*6
# Out:
# 20

# %%
(2+3)*6
# Out:
# 30

# %% [markdown]
# # The Integer, Floating Point and String Data Types

# %%
'Hello, world!
# Out:
#   File "C:\Users\Eugene Kwok Yau Seng\AppData\Local\Temp\ipykernel_15032\1551967912.py", line 1
#     'Hello, world!
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
# User forgot the final single quote character at the end of the string.

# %% [markdown]
# # String Concatenation and Replication

# %%
# + is the addition operator when it operates on two integers or floating-point values.
# When + is used on two string values, it joins the strings as the string concatenation operator.

# %%
'Alice'+ 'Bob'
# Out:
# 'AliceBob'

# %%
# if use + operator on a string and integer value, it will display an error message.

# %%
'Alice' + 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15032\3504299338.py in <module>
# ----> 1 'Alice' + 42
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # String replication

# %%
# * operator is used on one string value and one integer value, it becomes the string replication operator.

# %%
'Alice'* 5
# Out:
# 'AliceAliceAliceAliceAlice'

# %%
# * operator can be used with only two numeric values (for multiplication).

# %%
# Otherwise, Python will display an error message.

# %%
'Alice' * 'Bob'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15032\3965694959.py in <module>
# ----> 1 'Alice' * 'Bob'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'Alice' * 5.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15032\3253056715.py in <module>
# ----> 1 'Alice' * 5.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# # Storing Values in Variables

# %%
# A variable is like a box in the computer's memory where you can store a single value

# %% [markdown]
# #  Assignment Statements

# %%
# An assignment statement consists of a variable name, an equal sign and the value to be stored.

# %%
spam = 40

# %%
spam
# Out:
# 40

# %%
eggs = 2

# %%
spam + eggs
# Out:
# 42

# %%
spam + eggs + spam
# Out:
# 82

# %%
# Overwriting the variable

# %%
spam = spam + 2

# %%
spam
# Out:
# 42

# %%
# A variable is initialized (or created), the first time a value is stored in it. 
# After that, user can use it in expressions with other variables and values. 
# When a variable is assigned a new value, the old value is forgotten, which is why spam evaluated to 42 instead of 40.

# %%
spam = 'Hello'

# %%
spam
# Out:
# 'Hello'

# %%
spam = 'Goodbye'

# %%
spam
# Out:
# 'Goodbye'
